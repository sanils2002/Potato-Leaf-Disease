# %% [markdown]
# # Problem Statement
# Farmers every year face economic loss and crop waste due to various diseases in potato plants.  Early blight and Late blight are major disease of potato leaf. It is estimated that the major loss occurred in potato yield is due to these diseases. Thus the images are classified into 3 classes :
# - Healthy leaves
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.jW152ASG2nfRv_LCkYnzMQHaFj%26pid%3DApi&f=1" height='200' width="300"/>
#
# - Late Blight leaves
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.vCrNUKDj1Z1zErHEMQzmCQHaFj%26pid%3DApi&f=1" height='200' width="300"/>
#
# - Early Blight leaves
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.e4wvw_JVbE1yFgOYbUoVSAHaE7%26pid%3DApi&f=1" height='200' width="300"/>
#
# Project inspiration : https://youtube.com/playlist?list=PLeo1K3hjS3utJFNGyBpIvjWgSDY0eOE8S

# %%
# import libraries
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # to disable all debugging logs

# %%
# importing dataset
dir = os.listdir('../input/plant-village/PlantVillage')
for filenames in dir:
    print(filenames)
# Out:
# Pepper__bell___Bacterial_spot
# Potato___healthy
# Tomato_Leaf_Mold
# Tomato__Tomato_YellowLeaf__Curl_Virus
# Tomato_Bacterial_spot
# Tomato_Septoria_leaf_spot
# Tomato_healthy
# Tomato_Spider_mites_Two_spotted_spider_mite
# Tomato_Early_blight
# Tomato__Target_Spot
# Pepper__bell___healthy
# Potato___Late_blight
# Tomato_Late_blight
# Potato___Early_blight
# Tomato__Tomato_mosaic_virus

# %% [markdown]
# # Extracting only potato dataset

# %%
# !cp -rf ../input/plant-village/PlantVillage/Potato___Early_blight ./Potato___Early_blight

# %%
# !cp -rf ../input/plant-village/PlantVillage/Potato___Late_blight ./Potato___Late_blight

# %%
# !cp -rf ../input/plant-village/PlantVillage/Potato___healthy ./Potato___healthy

# %%
Current_Dir = os.getcwd()
dataset_dir = pathlib.Path(Current_Dir)
print(dataset_dir)
# Out:
# /kaggle/working

# %%
#Global initialization of some imp variables
Image_Size = 256
Batch_Size = 32
Channels = 3
Epochs = 40

# %%
#yields batches of images from the subdirectories class_a , class_b and class_c 
#together with labels 0 , 1 and 2 (0, 1, 2 corresponding to classes class_a , class_b and class_c respectively )
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir, batch_size = Batch_Size, image_size = (Image_Size, Image_Size), shuffle = True)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
#Folders(classes) in 'Dataset' directory
class_name = dataset.class_names
class_name
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset) # Number of Batches = (total number of files belonging to all classes / Batch_Size)
# Out:
# 68

# %%
print(dataset) #prints Elements in dataset: here 1st element is image and 2nd index of that image.
# Out:
# <BatchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
# Plotting the image
plt.figure(figsize = (15,15))
# dataset.take(count) : Creates a Dataset with at most 'count' elements(batch) from the dataset
for image, label in dataset.take(1): 
    for i in range(12):
        plt.subplot(3, 4, i+1) # many plots at a time =>subpots
        plt.imshow(image[i].numpy().astype('uint8')) #converting all data of image into numpy and than to intiger type as they were in float.
        plt.title(class_name[label[i]])  # title of the class_name of image
        plt.axis("off") # Hide the values of graph

# %% [markdown]
# # Splitting Dataset

# %%
# Function for Splitting the data
def split_dataset(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed = 10)
        
    ds_size = len(ds)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_data, val_data, test_data = split_dataset(dataset)

# %%
print("Size of Data is :{0} \nBatch size of Training Data is :{1}\nBatch size of Validation Data is :{2} \nBatch size of Testing Data is :{3} " .format(len(dataset), len(train_data), len(val_data), len(test_data)))
# Out:
# Size of Data is :68
# Batch size of Training Data is :54
# Batch size of Validation Data is :6
# Batch size of Testing Data is :8

# %%
# caching,shuffle and prefetching the data
train_ds = train_data.cache().shuffle(100).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_data.cache().shuffle(100).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_data.cache().shuffle(100).prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# # Data Pre-processing

# %%
# Image Preprocessing : Rescaling and Resizing
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(Image_Size, Image_Size),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
# Data augmentation by flipping and rotating existing images
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(factor = 0.5)
])

# %% [markdown]
# # Model Building

# %%
# Creating Convolution layer 
input_shape = (Batch_Size, Image_Size, Image_Size, Channels)
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(128, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(128, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu'),
    layers.MaxPool2D((2,2)),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(64, activation = 'softmax'),

])


model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (32, 256, 256, 3)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (32, 256, 256, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (32, 254, 254, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (32, 127, 127, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (32, 125, 125, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (32, 62, 62, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (32, 60, 60, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (32, 30, 30, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (32, 28, 28, 64)          73792
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (32, 14, 14, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (32, 12, 12, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (32, 6, 6, 128)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (32, 4, 4, 64)            73792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (32, 2, 2, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (32, 256)                 0
# _________________________________________________________________
# dense (Dense)                (32, 128)                 32896
# _________________________________________________________________
# dense_1 (Dense)              (32, 64)                  8256
# =================================================================
# Total params: 346,176
# Trainable params: 346,176
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Optimizing the model 'SparseCategoricalCrossentropy'=>as there are many categorical classes of data
model.compile(
    optimizer = 'adam', 
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False), 
    metrics = ['accuracy'])

# %%
#Fit the model with training data and also pass validation data
history = model.fit(
train_data, epochs = Epochs, batch_size = Batch_Size, verbose = 1, validation_data = val_data)
# Out:
# Epoch 1/40
# 54/54 [==============================] - 81s 1s/step - loss: 1.1884 - accuracy: 0.4830 - val_loss: 0.8471 - val_accuracy: 0.6250
# Epoch 2/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.8084 - accuracy: 0.6127 - val_loss: 0.6971 - val_accuracy: 0.6771
# Epoch 3/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.6067 - accuracy: 0.7436 - val_loss: 0.5800 - val_accuracy: 0.7448
# Epoch 4/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.3950 - accuracy: 0.8269 - val_loss: 0.2362 - val_accuracy: 0.9010
# Epoch 5/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.3297 - accuracy: 0.8674 - val_loss: 0.2992 - val_accuracy: 0.8958
# Epoch 6/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.2543 - accuracy: 0.9008 - val_loss: 0.3412 - val_accuracy: 0.8869
# Epoch 7/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.2379 - accuracy: 0.9073 - val_loss: 0.1718 - val_accuracy: 0.9167
# Epoch 8/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.2569 - accuracy: 0.8996 - val_loss: 0.1051 - val_accuracy: 0.9583
# Epoch 9/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.2025 - accuracy: 0.9313 - val_loss: 0.4847 - val_accuracy: 0.7857
# Epoch 10/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.1697 - accuracy: 0.9349 - val_loss: 0.3679 - val_accuracy: 0.8594
# Epoch 11/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.1489 - accuracy: 0.9372 - val_loss: 0.1751 - val_accuracy: 0.9375
# Epoch 12/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.1041 - accuracy: 0.9624 - val_loss: 0.1187 - val_accuracy: 0.9479
# Epoch 13/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.0922 - accuracy: 0.9660 - val_loss: 0.3181 - val_accuracy: 0.9375
# Epoch 14/40
# 54/54 [==============================] - 79s 1s/step - loss: 0.0985 - accuracy: 0.9705 - val_loss: 0.1174 - val_accuracy: 0.9531
# Epoch 15/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.0724 - accuracy: 0.9707 - val_loss: 0.1563 - val_accuracy: 0.9531
# Epoch 16/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.0820 - accuracy: 0.9695 - val_loss: 0.1194 - val_accuracy: 0.9405
# Epoch 17/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.0710 - accuracy: 0.9759 - val_loss: 0.0729 - val_accuracy: 0.9740
# Epoch 18/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.0656 - accuracy: 0.9824 - val_loss: 0.1454 - val_accuracy: 0.9479
# Epoch 19/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.0845 - accuracy: 0.9677 - val_loss: 0.6879 - val_accuracy: 0.8155
# Epoch 20/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.0731 - accuracy: 0.9742 - val_loss: 0.2349 - val_accuracy: 0.9115
# Epoch 21/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.0508 - accuracy: 0.9826 - val_loss: 0.3533 - val_accuracy: 0.9062
# Epoch 22/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.0706 - val_accuracy: 0.9792
# Epoch 23/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.0462 - accuracy: 0.9859 - val_loss: 0.0671 - val_accuracy: 0.9635
# Epoch 24/40
# 54/54 [==============================] - 75s 1s/step - loss: 0.0316 - accuracy: 0.9888 - val_loss: 0.0295 - val_accuracy: 0.9896
# Epoch 25/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.0668 - accuracy: 0.9783 - val_loss: 0.1486 - val_accuracy: 0.9219
# Epoch 26/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.0472 - accuracy: 0.9842 - val_loss: 0.1140 - val_accuracy: 0.9740
# Epoch 27/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 0.0360 - val_accuracy: 0.9844
# Epoch 28/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.0272 - accuracy: 0.9902 - val_loss: 0.4423 - val_accuracy: 0.8854
# Epoch 29/40
# 54/54 [==============================] - 75s 1s/step - loss: 0.0492 - accuracy: 0.9842 - val_loss: 0.2458 - val_accuracy: 0.9286
# Epoch 30/40
# 54/54 [==============================] - 75s 1s/step - loss: 0.0434 - accuracy: 0.9836 - val_loss: 0.0816 - val_accuracy: 0.9688
# Epoch 31/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.0818 - accuracy: 0.9777 - val_loss: 0.1867 - val_accuracy: 0.9427
# Epoch 32/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.1090 - accuracy: 0.9548 - val_loss: 0.0384 - val_accuracy: 0.9948
# Epoch 33/40
# 54/54 [==============================] - 77s 1s/step - loss: 0.0332 - accuracy: 0.9884 - val_loss: 0.0347 - val_accuracy: 0.9896
# Epoch 34/40
# 54/54 [==============================] - 75s 1s/step - loss: 0.0206 - accuracy: 0.9918 - val_loss: 0.0903 - val_accuracy: 0.9740
# Epoch 35/40
# 54/54 [==============================] - 76s 1s/step - loss: 0.0385 - accuracy: 0.9865 - val_loss: 0.1267 - val_accuracy: 0.9635
# Epoch 36/40
# 54/54 [==============================] - 78s 1s/step - loss: 0.0407 - accuracy: 0.9883 - val_loss: 0.0753 - val_accuracy: 0.9792
# Epoch 37/40
# 54/54 [==============================] - 80s 1s/step - loss: 0.0400 - accuracy: 0.9865 - val_loss: 0.0219 - val_accuracy: 0.9881
# Epoch 38/40
# 54/54 [==============================] - 85s 2s/step - loss: 0.0543 - accuracy: 0.9809 - val_loss: 0.1023 - val_accuracy: 0.9583
# Epoch 39/40
# 54/54 [==============================] - 80s 1s/step - loss: 0.0265 - accuracy: 0.9924 - val_loss: 0.0191 - val_accuracy: 0.9948
# Epoch 40/40
# 54/54 [==============================] - 83s 2s/step - loss: 0.0187 - accuracy: 0.9935 - val_loss: 0.0709 - val_accuracy: 0.9740

# %%
scores = model.evaluate(train_data)
# Out:
# 54/54 [==============================] - 17s 302ms/step - loss: 0.0716 - accuracy: 0.9765

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 40, 'steps': 54}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Analyzing the Output

# %%
# Getting the model history to analyse
train_loss = history.history['loss']
train_acc = history.history['accuracy']

val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']

# %%
#graphs for accuracy and loss of training and validation data
plt.figure(figsize = (15,15))
plt.subplot(2,3,1)
plt.plot(range(Epochs), train_acc, label = 'Training Accuracy')
plt.plot(range(Epochs), val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy') 

plt.subplot(2,3,2)
plt.plot(range(Epochs), train_loss, label = 'Training Loss')
plt.plot(range(Epochs), val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
#plotting image
for batch_image, batch_label in train_data.take(1):
    first_image = batch_image[0].numpy().astype('uint8')
    first_label = class_name[batch_label[0]]
    
    print('First Image of batch to predict :')
    plt.imshow(first_image)
    print('Actual label : ', first_label)
    
    batch_prediction = model.predict(batch_image)
    print('Predicted label : ', class_name[np.argmax(batch_prediction[0])])
    plt.axis('off')
# Out:
# First Image of batch to predict :
# Actual label :  Potato___Early_blight
# Predicted label :  Potato___Early_blight

# %%
# plotting batch of images with its actual label, predicted label and confidence
plt.figure(figsize = (16,16))
for batch_image, batch_label in train_data.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        image = batch_image[i].numpy().astype('uint8')
        label = class_name[batch_label[i]]
    
        plt.imshow(image)
    
        batch_prediction = model.predict(batch_image)
        predicted_class = class_name[np.argmax(batch_prediction[i])]
        confidence = round(np.max(batch_prediction[i]) * 100, 2)
        
        plt.title(f'Actual : {label},\n Prediction : {predicted_class},\n Confidence : {confidence}%')
    
        plt.axis('off')

# %% [markdown]
# ### The Model shows accuracy > 97%
